# %%
# %load_ext autoreload
# %autoreload 2
import sys, os, platform
import os
import sys
module_path = os.path.abspath(os.path.join('../spectraltree'))
if module_path not in sys.path:
    sys.path.append(module_path)
#sys.path.append(os.path.join(os.path.dirname(sys.path[0]),'spectraltree'))
#sys.path.append(os.path.join(sys.path[0],'spectraltree'))
import pickle
import reconstruct_tree as rt
import utils
import generation
import compare_methods
import numpy as np
from dendropy.interop import raxml
from dendropy.model.discrete import simulate_discrete_chars, Jc69
from dendropy.calculate.treecompare import symmetric_difference
import seaborn as sns
import matplotlib.pylab as plt

# %%
m_vec = np.arange(100,550,100)
print(m_vec)
num_reps = 10
#tree_list = [utils.lopsided_tree(utils.default_namespace(m), m) for m in m_vec]
tree_list = [utils.lopsided_tree(m,utils.default_namespace(m)) for m in m_vec]
jc = generation.Jukes_Cantor()
delta_vec = [0.92]
NJ = rt.NeighborJoining(rt.JC_similarity_matrix)
SNJ = rt.SpectralNeighborJoining(rt.JC_similarity_matrix)
methods = [NJ,SNJ]
mutation_rates = [jc.similarity2t(delta)  for delta in delta_vec]
Ns = [2000]
results = compare_methods.experiment(tree_list = tree_list, sequence_model = jc, Ns = Ns, methods=methods, mutation_rates = mutation_rates, reps_per_tree=num_reps,savepath='caterpillar_delta_92.pkl',folder = '../data/',overwrite=True)
# Out:
# [100 200 300 400 500]
# ==== Beginning Experiment =====
# 	 Transition:  Jukes Cantor
# 	 5 trees
# 	 1 sample sizes: 2000
# 	 2 methods <reconstruct_tree.NeighborJoining object at 0x7f9d8c068278> <reconstruct_tree.SpectralNeighborJoining object at 0x7f9d8c068ba8>
# 	 1 mutation rates: 0.0208
# 	 10 reps
# 1 / 100
# 2 / 100
# 3 / 100
# 4 / 100
# 5 / 100
# 6 / 100
# 7 / 100
# 8 / 100
# 9 / 100
# 10 / 100
# 11 / 100
# 12 / 100
# 13 / 100
# 14 / 100
# 15 / 100
# 16 / 100
# 17 / 100
# 18 / 100
# 19 / 100
# 20 / 100
# 21 / 100

# %%
jc = generation.Jukes_Cantor()
df = compare_methods.results2frame(results)
df['RF_log'] = np.log(1+df['RF'])
sns.set_style("whitegrid")
plt.rcParams.update({'font.size': 14})
h = compare_methods.accuracy(df,x="m",y="RF_log")
h.set(ylim=(0,10))
new_labels = ['NJ', 'SNJ']
ax = plt.gca()
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, new_labels)
plt.ylabel(r'log(1+RF)')
plt.xlabel(r'$\delta$')

plt.savefig('../data/caterpillar_n_2000_delta_92_scan_m.eps',format='eps')
# Out:
# m
# 100    20
# 200    20
# 300    20
# 400    20
# 500    20
# Name: RF_log, dtype: int64

# %%
f = open('../data/caterpillar_delta_92.pkl','rb')
results = pickle.load(f)

# %%
print(compare_methods.results2frame(results))
# Out:
# F1%   RF  correct    m  \
# 0    98.989899    4    False  100
# 1    97.979798    8    False  100
# 2    99.494949    2    False  100
# 3    97.979798    8    False  100
# 4    99.494949    2    False  100
# 5    99.494949    2    False  100
# 6    98.484848    6    False  100
# 7   100.000000    0     True  100
# 8   100.000000    0     True  100
# 9    94.949495   20    False  100
# 10  100.000000    0     True  100
# 11   97.474747   10    False  100
# 12  100.000000    0     True  100
# 13  100.000000    0     True  100
# 14  100.000000    0     True  100
# 15   98.989899    4    False  100
# 16   98.989899    4    False  100
# 17   98.484848    6    False  100
# 18   97.979798    8    False  100
# 19   98.484848    6    False  100
# 20   86.180905  110    False  200
# 21   92.211055   62    False  200
# 22   91.206030   70    False  200
# 23   96.984925   24    False  200
# 24   88.190955   94    False  200
# 25   97.989950   16    False  200
# 26   85.175879  118    False  200
# 27   95.728643   34    False  200
# 28   84.924623  120    False  200
# 29   97.236181   22    False  200
# ..         ...  ...      ...  ...
# 70   57.142857  684    False  400
# 71   95.112782   78    False  400
# 72   64.160401  572    False  400
# 73   95.488722   72    False  400
# 74   70.175439  476    False  400
# 75   94.235589   92    False  400
# 76   69.548872  486    False  400
# 77   93.859649   98    False  400
# 78   63.659148  580    False  400
# 79   89.849624  162    False  400
# 80   66.132265  676    False  500
# 81   93.687375  126    False  500
# 82   57.815631  842    False  500
# 83   93.086172  138    False  500
# 84   64.128257  716    False  500
# 85   92.284569  154    False  500
# 86   50.801603  982    False  500
# 87   91.983968  160    False  500
# 88   57.615230  846    False  500
# 89   89.278557  214    False  500
# 90   62.725451  744    False  500
# 91   92.084168  158    False  500
# 92   62.424850  750    False  500
# 93   90.380762  192    False  500
# 94   58.617234  826    False  500
# 95   86.873747  262    False  500
# 96   60.721443  784    False  500
# 97   93.486974  130    False  500
# 98   63.226453  734    False  500
# 99   91.382766  172    False  500
#
#                                                method     n      rate  \
# 0   <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 1   <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 2   <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 3   <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 4   <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 5   <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 6   <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 7   <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 8   <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 9   <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 10  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 11  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 12  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 13  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 14  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 15  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 16  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 17  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 18  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 19  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 20  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 21  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 22  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 23  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 24  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 25  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 26  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 27  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 28  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 29  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# ..                                                ...   ...       ...
# 70  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 71  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 72  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 73  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 74  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 75  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 76  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 77  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 78  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 79  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 80  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 81  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 82  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 83  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 84  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 85  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 86  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 87  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 88  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 89  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 90  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 91  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 92  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 93  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 94  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 95  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 96  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 97  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
# 98  <reconstruct_tree.NeighborJoining object at 0x...  1000  0.020845
# 99  <reconstruct_tree.SpectralNeighborJoining obje...  1000  0.020845
#
#        runTime    transition
# 0     0.218584  Jukes Cantor
# 1     0.873911  Jukes Cantor
# 2     0.217690  Jukes Cantor
# 3     0.899419  Jukes Cantor
# 4     0.241096  Jukes Cantor
# 5     0.876982  Jukes Cantor
# 6     0.214587  Jukes Cantor
# 7     0.838248  Jukes Cantor
# 8     0.198367  Jukes Cantor
# 9     0.794460  Jukes Cantor
# 10    0.197843  Jukes Cantor
# 11    0.807698  Jukes Cantor
# 12    0.197776  Jukes Cantor
# 13    0.890995  Jukes Cantor
# 14    0.202618  Jukes Cantor
# 15    0.872931  Jukes Cantor
# 16    0.202404  Jukes Cantor
# 17    0.819273  Jukes Cantor
# 18    0.199043  Jukes Cantor
# 19    0.829304  Jukes Cantor
# 20    1.276052  Jukes Cantor
# 21   12.601496  Jukes Cantor
# 22    1.276604  Jukes Cantor
# 23   15.076434  Jukes Cantor
# 24    1.298017  Jukes Cantor
# 25   14.849572  Jukes Cantor
# 26    1.300225  Jukes Cantor
# 27   11.861767  Jukes Cantor
# 28    1.368614  Jukes Cantor
# 29   12.528980  Jukes Cantor
# ..         ...           ...
# 70    9.373362  Jukes Cantor
# 71  284.395535  Jukes Cantor
# 72    9.381263  Jukes Cantor
# 73  340.931705  Jukes Cantor
# 74    9.396959  Jukes Cantor
# 75  282.337919  Jukes Cantor
# 76    9.645607  Jukes Cantor
# 77  282.345298  Jukes Cantor
# 78   10.995895  Jukes Cantor
# 79  222.819554  Jukes Cantor
# 80   19.368788  Jukes Cantor
# 81  646.567404  Jukes Cantor
# 82   20.068459  Jukes Cantor
# 83  667.656724  Jukes Cantor
# 84   20.921489  Jukes Cantor
# 85  715.461506  Jukes Cantor
# 86   20.573577  Jukes Cantor
# 87  664.754223  Jukes Cantor
# 88   18.569613  Jukes Cantor
# 89  540.117180  Jukes Cantor
# 90   20.266368  Jukes Cantor
# 91  629.469460  Jukes Cantor
# 92   18.550797  Jukes Cantor
# 93  581.207303  Jukes Cantor
# 94   18.469128  Jukes Cantor
# 95  517.598968  Jukes Cantor
# 96   20.842969  Jukes Cantor
# 97  645.871133  Jukes Cantor
# 98   18.733079  Jukes Cantor
# 99  605.077756  Jukes Cantor
#
# [100 rows x 9 columns]
