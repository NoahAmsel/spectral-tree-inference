# %%
# %load_ext autoreload
# %autoreload 2
#import spectraltree as st
from spectraltree import *
from compare_methods import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import dendropy

# %%
ttt = unrooted_birth_death_tree(birth_rate=1., death_rate=0., num_total_tips=64)
set_edge_lengths(ttt,value = 1)

ttt.print_plot(width=80)
#ttt.is_rooted = False
# Out:
#                                              /------------------------------ T29
#                                              |
#                                       /------+       /---------------------- T62
#                                       |      |       |
#                                       |      \-------+              /------- T14
#                                       |              |      /-------+
#                                       |              \------+       \------- T45
#                                       |                     |
#                                       |                     \--------------- T40
#                                       |
#                /----------------------+                             /------- T55
#                |                      |              /--------------+
#                |                      |              |              \------- T53
#                |                      |              |
#                |                      |      /-------+              /------- T9
#                |                      |      |       |      /-------+
#                |                      |      |       |      |       \------- T59
#                |                      |      |       \------+
#                |                      |      |              |       /------- T5
#                |                      \------+              \-------+
#                |                             |                      \------- T42
#                |                             |
#                |                             |                      /------- T38
#                |                             |              /-------+
#                |                             \--------------+       \------- T49
#                |                                            |
#        /-------+                                            \--------------- T23
#        |       |
#        |       |                                                    /------- T35
#        |       |                                            /-------+
#        |       |                             /--------------+       \------- T31
#        |       |                             |              |
#        |       |      /----------------------+              \--------------- T2
#        |       |      |                      |
#        |       |      |                      |       /---------------------- T13
#        |       |      |                      \-------+
#        |       |      |                              |      /--------------- T30
#        |       |      |                              \------+
#        |       |      |                                     |       /------- T20
#        |       |      |                                     \-------+
#        |       |      |                                             \------- T54
#        |       |      |
#        |       |      |                                             /------- T50
#        |       \------+                      /----------------------+
#        |              |                      |                      \------- T17
#        |              |                      |
#        |              |               /------+              /--------------- T48
#        |              |               |      |       /------+
# /------+              |               |      |       |      |       /------- T6
# |      |              |               |      \-------+      \-------+
# |      |              |       /-------+              |              \------- T63
# |      |              |       |       |              |
# |      |              |       |       |              \---------------------- T60
# |      |              |       |       |
# |      |              |       |       \------------------------------------- T33
# |      |              \-------+
# |      |                      |                                     /------- T51
# |      |                      |                             /-------+
# |      |                      |                      /------+       \------- T39
# |      |                      |                      |      |
# |      |                      \----------------------+      \--------------- T34
# |      |                                             |
# |      |                                             \---------------------- T16
# |      |
# |      |                                                            /------- T3
# |      |                                             /--------------+
# |      |                                             |              \------- T24
# |      |                                     /-------+
# |      |                                     |       |              /------- T57
# |      |                                     |       |      /-------+
# |      \-------------------------------------+       \------+       \------- T28
# |                                            |              |
# |                                            |              \--------------- T43
# +                                            |
# |                                            \------------------------------ T36
# |
# |                     /----------------------------------------------------- T46
# |                     |
# |                     |                              /---------------------- T15
# |                     |                      /-------+
# |                     |                      |       |      /--------------- T11
# |                     |                      |       \------+
# |                     |                      |              |       /------- T22
# |                     |                      |              \-------+
# |                     |               /------+                      \------- T7
# |                     |               |      |
# |                     |               |      |                      /------- T1
# |              /------+               |      |              /-------+
# |              |      |               |      |              |       \------- T19
# |              |      |               |      \--------------+
# |              |      |               |                     |       /------- T8
# |              |      |       /-------+                     \-------+
# |              |      |       |       |                             \------- T56
# |              |      |       |       |
# |              |      |       |       |                     /--------------- T44
# |              |      |       |       |              /------+
# |              |      |       |       |              |      |       /------- T27
# |              |      |       |       |              |      \-------+
# |              |      \-------+       \--------------+              \------- T61
# \--------------+              |                      |
#                |              |                      |              /------- T26
#                |              |                      \--------------+
#                |              |                                     \------- T10
#                |              |
#                |              |                                     /------- T41
#                |              \-------------------------------------+
#                |                                                    \------- T18
#                |
#                |              /--------------------------------------------- T21
#                |              |
#                |              |                             /--------------- T4
#                |              |       /---------------------+
#                \--------------+       |                     |       /------- T32
#                               |       |                     \-------+
#                               |       |                             \------- T37
#                               |       |
#                               \-------+              /---------------------- T52
#                                       |              |
#                                       |      /-------+              /------- T12
#                                       |      |       |      /-------+
#                                       |      |       \------+       \------- T64
#                                       \------+              |
#                                              |              \--------------- T25
#                                              |
#                                              |                      /------- T47
#                                              \----------------------+
#                                                                     \------- T58

# %%
trees = [ttt]
for t in trees:
    set_edge_lengths(t, value=1.)
jc = Jukes_Cantor()
delta_vec = np.linspace(0.65,0.95,7)
mutation_rates = [jc.similarity2t(delta)  for delta in delta_vec]
Ns = np.linspace(50,1000,20).astype(int)
methods = [Reconstruction_Method(neighbor_joining), Reconstruction_Method(estimate_tree_topology)]

# %%
results = experiment(tree_list=trees,
                        sequence_model=jc,
                        Ns=Ns,
                        methods=methods,
                        reps_per_tree=1,
                        mutation_rates=mutation_rates,

                     savepath="grid_search_nonsymmetric_m_512.pkl", overwrite=True)
# Out:
# ==== Beginning Experiment =====
# 	 Transition:  Jukes Cantor
# 	 1 trees
# 	 20 sample sizes: 50 100 150 200 250 300 350 400 450 500 550 600 650 700 750 800 850 900 950 1000
# 	 2 methods NJ sv2
# 	 7 mutation rates: 0.1077 0.0892 0.0719 0.0558 0.0406 0.0263 0.0128
# 	 1 reps
# 1 / 280
# 2 / 280
# 3 / 280
# 4 / 280
# 5 / 280
# 6 / 280
# 7 / 280
# 8 / 280
# 9 / 280
# 10 / 280
# 11 / 280
# 12 / 280
# 13 / 280
# 14 / 280
# 15 / 280
# 16 / 280
# 17 / 280
# 18 / 280
# 19 / 280
# 20 / 280
# 21 / 280
# 22 / 280
# 23 / 280
# 24 / 280
# 25 / 280
# 26 / 280
# 27 / 280
# 28 / 280
# 29 / 280
# 30 / 280
# 31 / 280
# 32 / 280
# 33 / 280
# 34 / 280
# 35 / 280
# 36 / 280
# 37 / 280
# 38 / 280
# 39 / 280
# 40 / 280
# 41 / 280
# 42 / 280
# 43 / 280
# 44 / 280
# 45 / 280
# 46 / 280
# 47 / 280
# 48 / 280
# 49 / 280
# 50 / 280
# 51 / 280
# 52 / 280
# 53 / 280
# 54 / 280
# 55 / 280
# 56 / 280
# 57 / 280
# 58 / 280
# 59 / 280
# 60 / 280
# 61 / 280
# 62 / 280
# 63 / 280
# 64 / 280
# 65 / 280
# 66 / 280
# 67 / 280
# 68 / 280
# 69 / 280
# 70 / 280
# 71 / 280
# 72 / 280
# 73 / 280
# 74 / 280
# 75 / 280
# 76 / 280
# 77 / 280
# 78 / 280
# 79 / 280
# 80 / 280
# 81 / 280
# 82 / 280
# 83 / 280
# 84 / 280
# 85 / 280
# 86 / 280
# 87 / 280
# 88 / 280
# 89 / 280
# 90 / 280
# 91 / 280
# 92 / 280
# 93 / 280
# 94 / 280
# 95 / 280
# 96 / 280
# 97 / 280
# 98 / 280
# 99 / 280
# 100 / 280
# 101 / 280
# 102 / 280
# 103 / 280
# 104 / 280
# 105 / 280
# 106 / 280
# 107 / 280
# 108 / 280
# 109 / 280
# 110 / 280
# 111 / 280
# 112 / 280
# 113 / 280
# 114 / 280
# 115 / 280
# 116 / 280
# 117 / 280
# 118 / 280
# 119 / 280
# 120 / 280
# 121 / 280
# 122 / 280
# 123 / 280
# 124 / 280
# 125 / 280
# 126 / 280
# 127 / 280
# 128 / 280
# 129 / 280
# 130 / 280
# 131 / 280
# 132 / 280
# 133 / 280
# 134 / 280
# 135 / 280
# 136 / 280
# 137 / 280
# 138 / 280
# 139 / 280
# 140 / 280
# 141 / 280
# 142 / 280
# 143 / 280
# 144 / 280
# 145 / 280
# 146 / 280
# 147 / 280
# 148 / 280
# 149 / 280
# 150 / 280
# 151 / 280
# 152 / 280
# 153 / 280
# 154 / 280
# 155 / 280
# 156 / 280
# 157 / 280
# 158 / 280
# 159 / 280
# 160 / 280
# 161 / 280
# 162 / 280
# 163 / 280
# 164 / 280
# 165 / 280
# 166 / 280
# 167 / 280
# 168 / 280
# 169 / 280
# 170 / 280
# 171 / 280
# 172 / 280
# 173 / 280
# 174 / 280
# 175 / 280
# 176 / 280
# 177 / 280
# 178 / 280
# 179 / 280
# 180 / 280
# 181 / 280
# 182 / 280
# 183 / 280
# 184 / 280
# 185 / 280
# 186 / 280
# 187 / 280
# 188 / 280
# 189 / 280
# 190 / 280
# 191 / 280
# 192 / 280
# 193 / 280
# 194 / 280
# 195 / 280
# 196 / 280
# 197 / 280
# 198 / 280
# 199 / 280
# 200 / 280
# 201 / 280
# 202 / 280
# 203 / 280
# 204 / 280
# 205 / 280
# 206 / 280
# 207 / 280
# 208 / 280
# 209 / 280
# 210 / 280
# 211 / 280
# 212 / 280
# 213 / 280
# 214 / 280
# 215 / 280
# 216 / 280
# 217 / 280
# 218 / 280
# 219 / 280
# 220 / 280
# 221 / 280
# 222 / 280
# 223 / 280
# 224 / 280
# 225 / 280
# 226 / 280
# 227 / 280
# 228 / 280
# 229 / 280
# 230 / 280
# 231 / 280
# 232 / 280
# 233 / 280
# 234 / 280
# 235 / 280
# 236 / 280
# 237 / 280
# 238 / 280
# 239 / 280
# 240 / 280
# 241 / 280
# 242 / 280
# 243 / 280
# 244 / 280
# 245 / 280
# 246 / 280
# 247 / 280
# 248 / 280
# 249 / 280
# 250 / 280
# 251 / 280
# 252 / 280
# 253 / 280
# 254 / 280
# 255 / 280
# 256 / 280
# 257 / 280
# 258 / 280
# 259 / 280
# 260 / 280
# 261 / 280
# 262 / 280
# 263 / 280
# 264 / 280
# 265 / 280
# 266 / 280
# 267 / 280
# 268 / 280
# 269 / 280
# 270 / 280
# 271 / 280
# 272 / 280
# 273 / 280
# 274 / 280
# 275 / 280
# 276 / 280
# 277 / 280
# 278 / 280
# 279 / 280
# 280 / 280
# Saved to data/grid_search_nonsymmetric_m_512.pkl

# %%
df = results2frame(results)

# %%
accuracy(df, col="rate")
# Out:
# rate      n
# 0.012823  50      2
#           100     2
#           150     2
#           200     2
#           250     2
#                  ..
# 0.107696  800     2
#           850     2
#           900     2
#           950     2
#           1000    2
# Name: F1%, Length: 140, dtype: int64
